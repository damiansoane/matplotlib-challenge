# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
mouse_drug_data_to_load = "data/mouse_drug_data.csv"
clinical_trial_data_to_load = "data/clinicaltrial_data.csv"

# Read the Mouse and Drug Data and the Clinical Trial Data

mouse_data = pd.read_csv(mouse_drug_data_to_load)
cl_data = pd.read_csv(clinical_trial_data_to_load)
# Combine the data into a single dataset
data = pd.merge(cl_data, mouse_data, how="left", on=("Mouse ID", "Mouse ID"))

# Display the data table for preview

data
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites       Drug
# 0        b128          0           45.000000                 0  Capomulin
# 1        f932          0           45.000000                 0   Ketapril
# 2        g107          0           45.000000                 0   Ketapril
# 3        a457          0           45.000000                 0   Ketapril
# 4        c819          0           45.000000                 0   Ketapril
# ...       ...        ...                 ...               ...        ...
# 1901     r944         45           41.581521                 2  Capomulin
# 1902     u364         45           31.023923                 3  Capomulin
# 1903     p438         45           61.433892                 1   Ceftamin
# 1904     x773         45           58.634971                 4    Placebo
# 1905     b879         45           72.555239                 2   Stelasyn
#
# [1906 rows x 5 columns]

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 
mean_tumor_vol = data.groupby(["Drug", "Timepoint"]).mean()["Tumor Volume (mm3)"]
# Convert to DataFrame
mean_tumor_vol = pd.DataFrame(mean_tumor_vol)
# Preview DataFrame
mean_tumor_vol
# Out:
#                      Tumor Volume (mm3)
# Drug      Timepoint
# Capomulin 0                   45.000000
#           5                   44.266086
#           10                  43.084291
#           15                  42.064317
#           20                  40.716325
# ...                                 ...
# Zoniferol 25                  55.432935
#           30                  57.713531
#           35                  60.089372
#           40                  62.916692
#           45                  65.960888
#
# [100 rows x 1 columns]

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
se_tumor_vol = data.groupby(["Drug","Timepoint"]).sem()["Tumor Volume (mm3)"]
# Convert to DataFrame
se_tumor_vol = pd.DataFrame(se_tumor_vol)
# Preview DataFrame
se_tumor_vol
# Out:
#                      Tumor Volume (mm3)
# Drug      Timepoint
# Capomulin 0                    0.000000
#           5                    0.448593
#           10                   0.702684
#           15                   0.838617
#           20                   0.909731
# ...                                 ...
# Zoniferol 25                   0.602513
#           30                   0.800043
#           35                   0.881426
#           40                   0.998515
#           45                   1.003576
#
# [100 rows x 1 columns]

# %%
# Minor Data Munging to Re-Format the Data Frames
mean_tumor_vol = mean_tumor_vol.reset_index()
se_tumor_vol = se_tumor_vol.reset_index() 
mean_tumor_vol_new = mean_tumor_vol.pivot(index="Timepoint", columns="Drug")["Tumor Volume (mm3)"]
se_tumor_vol_new = se_tumor_vol.pivot(index="Timepoint", columns="Drug")["Tumor Volume (mm3)"]
# Preview that Reformatting worked

# %%
se_tumor_vol_new
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.448593  0.164505   0.235102  0.264819  0.202385  0.218091
# 10          0.702684  0.236144   0.282346  0.357421  0.319415  0.402064
# 15          0.838617  0.332053   0.357705  0.580268  0.444378  0.614461
# 20          0.909731  0.359482   0.476210  0.726484  0.595260  0.839609
# 25          0.881642  0.439356   0.550315  0.755413  0.813706  1.034872
# 30          0.934460  0.490620   0.631061  0.934121  0.975496  1.218231
# 35          1.052241  0.692248   0.984155  1.127867  1.013769  1.287481
# 40          1.223608  0.708505   1.055220  1.158449  1.118567  1.370634
# 45          1.223977  0.902358   1.144427  1.453186  1.416363  1.351726
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
mean_tumor_vol_new
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
# 25         39.939528  54.287674  55.715252  57.678982  56.731968  57.482574
# 30         38.769339  56.769517  58.299397  60.994507  59.559509  59.809063
# 35         37.816839  58.827548  60.742461  63.371686  62.685087  62.420615
# 40         36.958001  61.467895  63.162824  66.068580  65.600754  65.052675
# 45         36.236114  64.132421  65.755562  70.662958  69.265506  68.084082
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# ...

# %%
# Generate the Plot (with Error Bars)
plt.errorbar(mean_tumor_vol_new.index, mean_tumor_vol_new["Capomulin"], yerr=se_tumor_vol_new["Capomulin"], color="r", marker="o")
plt.errorbar(mean_tumor_vol_new.index, mean_tumor_vol_new["Infubinol"], yerr=se_tumor_vol_new["Infubinol"], color="b", marker="^")
plt.errorbar(mean_tumor_vol_new.index, mean_tumor_vol_new["Ketapril"], yerr=se_tumor_vol_new["Ketapril"], color="g", marker="s")
plt.errorbar(mean_tumor_vol_new.index, mean_tumor_vol_new["Placebo"], yerr=se_tumor_vol_new["Placebo"], color="k", marker="d")
plt.title("Tumor Response to Treatment")
plt.xlabel("Time (Days)")
plt.ylabel("Tumor Volume (mm3)")
plt.grid(True)
plt.legend(loc="best")
# Save the Figure
fig.savefig("analysis/Fig1.png")
# Out:
# No handles with labels found to put in legend.

# %%
# Show the Figure
plt.show()

# %% [markdown]
# ![Tumor Response to Treatment](../Images/treatment.png)

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint 
mean_met = data.groupby(["Drug", "Timepoint"]).mean()["Metastatic Sites"]
# Convert to DataFrame
mean_met = pd.DataFrame(mean_met)
# Preview DataFrame
mean_met
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.160000
#           10                 0.320000
#           15                 0.375000
#           20                 0.652174
# ...                               ...
# Zoniferol 25                 1.687500
#           30                 1.933333
#           35                 2.285714
#           40                 2.785714
#           45                 3.071429
#
# [100 rows x 1 columns]

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 
se_met = data.groupby(["Drug", "Timepoint"]).sem()["Metastatic Sites"]
# Convert to DataFrame
se_met = pd.DataFrame(se_met)
# Preview DataFrame
se_met
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.074833
#           10                 0.125433
#           15                 0.132048
#           20                 0.161621
# ...                               ...
# Zoniferol 25                 0.236621
#           30                 0.248168
#           35                 0.285714
#           40                 0.299791
#           45                 0.286400
#
# [100 rows x 1 columns]

# %%
# Minor Data Munging to Re-Format the Data Frames
mean_met = mean_met.reset_index()
se_met = se_met.reset_index()
mean_met_new = mean_met.pivot(index="Timepoint", columns="Drug")["Metastatic Sites"]
se_met_new = se_met.pivot(index="Timepoint", columns="Drug")["Metastatic Sites"]

# Preview that Reformatting worked
se_met_new
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.074833  0.108588   0.091652  0.098100  0.093618  0.100947
# 10          0.125433  0.152177   0.159364  0.142018  0.163577  0.115261
# 15          0.132048  0.180625   0.194015  0.191381  0.158651  0.190221
# 20          0.161621  0.241034   0.234801  0.236680  0.181731  0.234064
# 25          0.181818  0.258831   0.265753  0.288275  0.185240  0.263888
# 30          0.172944  0.249479   0.227823  0.347467  0.266667  0.300264
# 35          0.169496  0.266526   0.224733  0.361418  0.330464  0.341412
# 40          0.175610  0.289128   0.314466  0.315725  0.321702  0.297294
# 45          0.202591  0.286101   0.309320  0.278722  0.351104  0.304240
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
mean_met_new
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.160000  0.380952   0.280000  0.304348  0.260870  0.375000
# 10          0.320000  0.600000   0.666667  0.590909  0.523810  0.833333
# 15          0.375000  0.789474   0.904762  0.842105  0.857143  1.250000
# 20          0.652174  1.111111   1.050000  1.210526  1.150000  1.526316
# 25          0.818182  1.500000   1.277778  1.631579  1.500000  1.941176
# 30          1.090909  1.937500   1.588235  2.055556  2.066667  2.266667
# 35          1.181818  2.071429   1.666667  2.294118  2.266667  2.642857
# 40          1.380952  2.357143   2.100000  2.733333  2.466667  3.166667
# 45          1.476190  2.692308   2.111111  3.363636  2.538462  3.272727
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
# Generate the Plot (with Error Bars)
plt.errorbar(mean_met_new.index, mean_met_new["Capomulin"], yerr=se_met_new["Capomulin"], color="r", marker="o")
plt.errorbar(mean_met_new.index, mean_met_new["Infubinol"], yerr=se_met_new["Infubinol"], color="b", marker="^")
plt.errorbar(mean_met_new.index, mean_met_new["Ketapril"], yerr=se_met_new["Ketapril"], color="g", marker="s")
plt.errorbar(mean_met_new.index, mean_met_new["Placebo"], yerr=se_met_new["Placebo"], color="k", marker="d")
plt.title("Metastatic Spread During Treatment")
plt.xlabel("Treatment Duration (Days)")
plt.ylabel("Met. Sites")
plt.grid(True)
plt.legend((line1, line2, line3), ('label1', 'label2', 'label3'))
# Save the Figure
fig.savefig("analysis/Fig2.png")
# Show the Figure
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-177-26f56ac42462> in <module>
#       8 plt.ylabel("Met. Sites")
#       9 plt.grid(True)
# ---> 10 plt.legend((line1, line2, line3), ('label1', 'label2', 'label3'))
#      11 # Save the Figure
#      12 fig.savefig("analysis/Fig2.png")
#
# NameError: name 'line1' is not defined

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/spread.png)

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)
survival_rate = data.groupby(["Drug", "Timepoint"]).count()["Tumor Volume (mm3)"]
# Convert to DataFrame
survival_rate = pd.DataFrame({"Mouse Count": survival_rate})
# Preview DataFrame
survival_rate
# Out:
#                      Mouse Count
# Drug      Timepoint
# Capomulin 0                   25
#           5                   25
#           10                  25
#           15                  24
#           20                  23
# ...                          ...
# Zoniferol 25                  16
#           30                  15
#           35                  14
#           40                  14
#           45                  14
#
# [100 rows x 1 columns]

# %%
# Minor Data Munging to Re-Format the Data Frames
survival_rate = survival_rate.reset_index()
survival_rate_new = survival_rate.pivot(index="Timepoint", columns="Drug")["Mouse Count"]
# Preview the Data Frame
survival_rate_new
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
# 25                22        18         18        19        18       17
# 30                22        16         17        18        15       15
# 35                22        14         12        17        15       14
# 40                21        14         10        15        15       12
# 45                21        13          9        11        13       11
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                26        25        26         25
# 5                25        25        25         24
# ...

# %%
# Generate the Plot (Accounting for percentages)
plt.plot(100*survival_rate_new["Capomulin"]/25, color="r", marker="o")
plt.plot(100*survival_rate_new["Infubinol"]/25, color="b", marker="^")
plt.plot(100*survival_rate_new["Ketapril"]/25, color="g", marker="s")
plt.plot(100*survival_rate_new["Placebo"]/25, color="k", marker="d")
plt.title("Survival During Treatment")
plt.xlabel("Time (Days))")
plt.ylabel("Survival Rate (%)")
plt.grid(True)
ax.legend(loc="best")
# Save the Figure
fig.savefig("analysis/Fig3.png")
# Show the Figure
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/survival.png)

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug
p_change = 100 * (mean_tumor_vol_new.iloc[-1] - mean_tumor_vol_new.iloc[0]) / mean_tumor_vol_new.iloc[0]
# Display the data to confirm
p_change
# Out:
# Drug
# Capomulin   -19.475303
# Ceftamin     42.516492
# Infubinol    46.123472
# Ketapril     57.028795
# Naftisol     53.923347
# Placebo      51.297960
# Propriva     47.241175
# Ramicane    -22.320900
# Stelasyn     52.085134
# Zoniferol    46.579751
# dtype: float64

# %%
# Store all Relevant Percent Changes into a Tuple
pcts = (p_change["Capomulin"],p_change["Infubinol"],p_change["Ketapril"],p_change["Placebo"])

# Splice the data between passing and failing drugs
fig,ax = plt.subplots()
arange = np.arange(len(pcts))
passing = ax.bar(ind[0:],pcts[0:], color="g")
failing = ax.bar(ind[1:],pcts[1:], color='r')

# Orient widths. Add labels, tick marks, etc. 
ax.grid(True)
ax.set_xticklabels(("Capomulin", "Infubinol","Ketapril","Placebo"))
ax.set_xticks(arange)
ax.set_title("Tumor Change Over 45 Day Treatment")
ax.set_ylabel("Percent Tumor Volume Change")
ax.set_ylim([-25,65])

# Use functions to label the percentages of changes
def autolabels(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 5,
                '%d' % int(height) + "%", 
                ha='center', color='w')
         
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., -18,
                '%d' % int(height) + "%", 
                ha='center', color='w')
# Call functions to implement the function calls

autolabels(failing)
autolabel(passing)

# Save the Figure
fig.savefig("analysis/Fig4.png")

# Show the Figure

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/change.png)
